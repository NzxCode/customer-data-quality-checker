# %%
nama = "Nicolas"
email = "gabnicol0807@gmail.com"
umur = 18
jenis_orderan = "Makanan"
jenis_makanan = "Makanan Berat"
harga = 25000
status_pembayaran = True

# %%
type(nama)
# Out:
# str

# %%
type(email)
# Out:
# str

# %%
type(umur)
# Out:
# int

# %%
type(jenis_orderan)
# Out:
# str

# %%
type(harga)
# Out:
# int

# %%
type(status_pembayaran)
# Out:
# bool
